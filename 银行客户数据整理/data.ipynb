# %%
import pandas as pd

# %%
# 读取数据
records = pd.read_csv("records.csv")
userInformation = pd.read_csv("user_information.csv")

# %%
# TODO 使用merge()函数
# 按照"id"这一列，合并records和userInformation
result = pd.merge(records,userInformation)

# TODO 使用groupby()函数和mean()函数
# 将newData按照"id"这一列进行分组与聚合
# 计算每个用户的平均记录次数，并赋值给变量groupByRecord
groupByRecord=result.groupby(result["id"]).mean()

# TODO 使用max()函数
# 获取groupByRecord["记录次数"]这一列的最大值，并赋值给timesMax
timesMax=groupByRecord["记录次数"].max()

# TODO 用布尔索引筛选出groupByRecord中
# 记录次数等于timesMax的数据，赋值给变量maxData
maxData=groupByRecord[groupByRecord["记录次数"]==timesMax]

# TODO 将maxData中"近6个月有交易月份数"列的值用value_counts()进行计数排序
# 并赋值给变量monthCount
monthCount=maxData["近6个月有交易月份数"].value_counts()

# TODO 输出monthCount
print(monthCount)
# Out:
# 近6个月有交易月份数
# 0.0    30
# 6.0    26
# 5.0    18
# 2.0    16
# 1.0    13
# 3.0    10
# 4.0     8
# Name: count, dtype: int64

# %%
maxData
# Out:
#        记录次数    账户收入比例    账户支出比例  外币比例  是否有房  是否有车  是否有孩  近6个月异地交易金额均值  \
# id
# 32     12.0  0.333333  0.002198   0.0   0.0   0.0   0.0    217.780000
# 93     12.0  0.390000  0.013919   0.0   0.0   0.0   0.0           NaN
# 369    12.0  0.226667  0.012015   0.0   0.0   0.0   0.0   5167.964000
# 560    12.0  0.150000  0.026520   0.0   0.0   0.0   0.0  24524.090000
# 593    12.0  0.240000  0.003663   0.0   0.0   0.0   0.0           NaN
# ...     ...       ...       ...   ...   ...   ...   ...           ...
# 9902   12.0  0.191667  0.015678   0.0   0.0   0.0   0.0   1591.480000
# 9945   12.0  0.148333  0.009377   0.0   0.0   0.0   0.0           NaN
# 9982   12.0  0.120000  0.002051   0.0   0.0   0.0   0.0   3667.126667
# 10005  12.0  0.390000  0.000000   0.0   0.0   0.0   0.0           NaN
# 10020  12.0  0.388333  0.002930   0.0   1.0   0.0   0.0           NaN
#
#         近6个月交易金额  近6个月有交易月份数
# id
# 32       1088.90         5.0
# 93           NaN         0.0
# 369     27918.82         6.0
# 560    147144.54         6.0
# 593          NaN         0.0
# ...          ...         ...
# 9902     1591.48         1.0
# 9945         NaN         0.0
# 9982    20486.01         3.0
# 10005        NaN         0.0
# 10020        NaN         0.0
#
# [121 rows x 10 columns]

# %%
groupByRecord
# Out:
#        记录次数    账户收入比例    账户支出比例  外币比例  是否有房  是否有车  是否有孩  近6个月异地交易金额均值  \
# id
# 0      10.5  0.178030  0.009158   0.0   0.0   0.0   0.0   1253.000000
# 1       2.5  0.104167  0.006105   0.0   0.0   0.0   0.0   3402.000000
# 2       9.0  0.105263  0.000386   0.0   0.0   0.0   1.0   2876.180000
# 3       5.0  0.208333  0.009657   0.0   0.0   0.0   0.0    521.000000
# 4       4.0  0.166667  0.002442   0.0   0.0   0.0   0.0           NaN
# ...     ...       ...       ...   ...   ...   ...   ...           ...
# 10026  11.0  0.458333  0.002070   0.0   0.0   0.0   0.0   9370.916667
# 10027   3.5  0.145833  0.068223   0.0   0.0   0.0   0.0    734.865000
# 10028   3.0  0.125000  0.007849   0.0   0.0   0.0   1.0   4388.765000
# 10029  10.5  0.125000  0.015485   0.0   0.0   0.0   0.0  98639.243330
# 10030   4.5  0.187500  0.019048   0.0   0.0   0.0   0.0   1074.185000
#
#         近6个月交易金额  近6个月有交易月份数
# id
# 0        3974.50         5.0
# 1        6804.00         2.0
# 2       14380.90         5.0
# 3         521.00         1.0
# 4            NaN         0.0
# ...          ...         ...
# 10026   61300.50         6.0
# 10027    2939.46         4.0
# 10028   17555.06         4.0
# 10029  296637.73         4.0
# 10030    4296.74         4.0
#
# [10031 rows x 10 columns]

# %%
timesMax
# Out:
# 12.0

# %%
monthCount
# Out:
# 近6个月有交易月份数
# 0.0    30
# 6.0    26
# 5.0    18
# 2.0    16
# 1.0    13
# 3.0    10
# 4.0     8
# Name: count, dtype: int64

# %%
# 导入matplotlib.pyplot
import matplotlib.pyplot as plt

# 通过给 plt.rcParams["font.sans-serif"] 赋值
# 将字体设置为 Arial Unicode MS 
plt.rcParams["font.sans-serif"] = "Arial Unicode MS"

# TODO 使用plt.bar()函数绘制柱状图
# 将x轴数据设置为monthCount.index，y轴数据设置为monthCount.values
plt.bar(monthCount.index,monthCount.values)

# 使用plt.show()函数显示图像
plt.show()
